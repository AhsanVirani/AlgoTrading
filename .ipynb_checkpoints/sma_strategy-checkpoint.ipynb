# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
plt.style.use("seaborn")

# %%
df = yf.download("TSLA", start="2010-01-01", end="2020-04-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df['Close'].plot(figsize=(12,8), title='TSLA/USD', fontsize=10)

# %%
# sma short and long
sma_s = 50
sma_l = 200

# %%
df['SMA_S'] = df['Close'].rolling(sma_s).mean()
df['SMA_L'] = df['Close'].rolling(sma_l).mean()

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-04-12    5.016000    5.042000    4.860000    4.930000    4.930000
# 2011-04-13    5.026000    5.138000    4.962000    4.986000    4.986000
# 2011-04-14    4.974000    5.056000    4.840000    5.028000    5.028000
# 2011-04-15    5.130000    5.236000    5.082000    5.116000    5.116000
# 2011-04-18    5.026000    5.124000    4.872000    5.006000    5.006000
# ...                ...         ...         ...         ...         ...
# 2020-04-23  145.520004  146.800003  140.626007  141.126007  141.126007
# 2020-04-24  142.162003  146.145996  139.636002  145.029999  145.029999
# 2020-04-27  147.522003  159.897995  147.000000  159.750000  159.750000
# 2020-04-28  159.128006  161.000000  151.337997  153.824005  153.824005
# 2020-04-29  158.033997  160.639999  156.632004  160.102005  160.102005
#
#                Volume      SMA_S     SMA_L  isLong
# Date
# 2011-04-12    6787000    4.79188   4.74527       1
# 2011-04-13    6057500    4.79596   4.74631       1
# 2011-04-14    4917000    4.80076   4.74762       1
# 2011-04-15    4717500    4.80856   4.75124       1
# 2011-04-18    5169500    4.81484   4.75707       1
# ...               ...        ...       ...     ...
# 2020-04-23   66183500  128.26972  83.08725       1
# 2020-04-24   66060000  128.10116  83.57348       1
# 2020-04-27  103407000  128.08016  84.13363       1
# 2020-04-28   76110000  127.95652  84.65767       1
# 2020-04-29   81080000  127.72496  85.20468       1
#
# [2277 rows x 9 columns]

# %%
df.dropna(inplace=True)

# %%
df[['Close', 'SMA_S', 'SMA_L']].plot(figsize=(12,8), 
                                    title='TESLA/USD - SMA{} | SMA{}'.format(sma_s, sma_l),
                                    fontsize=14)
plt.legend()
plt.show()

# %%
# Longs shown only. Shorts later!
df[['Close', 'SMA_S', 'SMA_L']].plot(figsize=(12,8), 
                                    title='TESLA/USD - SMA{} | SMA{}'.format(sma_s, sma_l),
                                    fontsize=14, linewidth=1, color=['yellow', 'grey', 'pink'])
plt.scatter(df.index, df['l_buy'], color='green', label='Buy Signal', marker='^', alpha=1)
plt.scatter(df.index, df['l_sell'], color='red', label='Sell Signal', marker='v', alpha=1)

# plt.scatter(my_stocks.index, my_stocks['Buy_Signal_Price'], color = 'green', label='Buy Signal', marker = '^', alpha = 1)
# plt.scatter(my_stocks.index, my_stocks['Sell_Signal_Price'], color = 'red', label='Sell Signal', marker = 'v', alpha = 1)
plt.legend()
plt.show()

# %%
df["isLong"] = np.where(df["SMA_S"] > df["SMA_L"], 1, -1)

# %% [markdown]
# # Buy and Sell Price

# %%
# For long --> buy_long, sell_long
l_buy = []
l_sell = []
flag = 1
for i in range(len(df)):
    if df['SMA_S'][i] > df['SMA_L'][i] and flag==1:
        l_buy.append(df['Close'][i])
        l_sell.append(np.nan)
        flag=-1
    elif df['SMA_S'][i] < df['SMA_L'][i] and flag==-1:
        l_sell.append(df['Close'][i])
        l_buy.append(np.nan)
        flag=1
    else:
        l_buy.append(np.nan)
        l_sell.append(np.nan)

# %%
df['l_buy'], df['l_sell'] = l_buy, l_sell

# %% [markdown]
# # BackTesting

# %%
# Adding returns
df['returns'] = np.log(df['Close'].div(df['Close'].shift(1)))

# %%
df['strategy'] = df['isLong'].shift(1) * df['returns']

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Buy & Hold strategy returns 350%
# # SMA strategy returns ony 100%

# %%
df[['returns', 'strategy']].sum()
# Out:
# returns     3.480472
# strategy    0.978869
# dtype: float64

# %%
# Dollar value invested
df[['returns', 'strategy']].sum().apply(np.exp)
# Out:
# returns     32.475053
# strategy     2.661444
# dtype: float64

# %%
# Mean annualised returns 
df[['returns', 'strategy']].mean() * 252
# Out:
# returns     0.385360
# strategy    0.108381
# dtype: float64

# %%
# Annualised risk
df[['returns', 'strategy']].std() * np.sqrt(252)
# Out:
# returns     0.532018
# strategy    0.532528
# dtype: float64

# %%
df['creturns'] = df['returns'].cumsum().apply(np.exp)
df['cstrategy'] = df['strategy'].cumsum().apply(np.exp)

# %%
df[['creturns', 'cstrategy']].plot(figsize=(12,8), title="TESLA/USD - BUY & HOLD vs SMA")
plt.legend()
plt.show()

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-04-13    5.026000    5.138000    4.962000    4.986000    4.986000
# 2011-04-14    4.974000    5.056000    4.840000    5.028000    5.028000
# 2011-04-15    5.130000    5.236000    5.082000    5.116000    5.116000
# 2011-04-18    5.026000    5.124000    4.872000    5.006000    5.006000
# 2011-04-19    5.052000    5.052000    4.930000    5.032000    5.032000
# ...                ...         ...         ...         ...         ...
# 2020-04-23  145.520004  146.800003  140.626007  141.126007  141.126007
# 2020-04-24  142.162003  146.145996  139.636002  145.029999  145.029999
# 2020-04-27  147.522003  159.897995  147.000000  159.750000  159.750000
# 2020-04-28  159.128006  161.000000  151.337997  153.824005  153.824005
# 2020-04-29  158.033997  160.639999  156.632004  160.102005  160.102005
#
#                Volume      SMA_S     SMA_L  isLong   returns  strategy  \
# Date
# 2011-04-13    6057500    4.79596   4.74631       1  0.011295  0.011295
# 2011-04-14    4917000    4.80076   4.74762       1  0.008388  0.008388
# 2011-04-15    4717500    4.80856   4.75124       1  0.017351  0.017351
# 2011-04-18    5169500    4.81484   4.75707       1 -0.021736 -0.021736
# 2011-04-19    2743500    4.82320   4.76612       1  0.005180  0.005180
# ...               ...        ...       ...     ...       ...       ...
# 2020-04-23   66183500  128.26972  83.08725       1 -0.036840 -0.036840
# 2020-04-24   66060000  128.10116  83.57348       1  0.027287  0.027287
# 2020-04-27  103407000  128.08016  84.13363       1  0.096669  0.096669
# 2020-04-28   76110000  127.95652  84.65767       1 -0.037801 -0.037801
# 2020-04-29   81080000  127.72496  85.20468       1  0.040002  0.040002
#
#              creturns  cstrategy
# Date
# 2011-04-13   1.011359   1.011359
# 2011-04-14   1.019878   1.019878
# 2011-04-15   1.037728   1.037728
# 2011-04-18   1.015416   1.015416
# 2011-04-19   1.020690   1.020690
# ...               ...        ...
# 2020-04-23  28.625966   2.345998
# 2020-04-24  29.417851   2.410895
# 2020-04-27  32.403652   2.655592
# 2020-04-28  31.201625   2.557082
# 2020-04-29  32.475053   2.661444
#
# [2276 rows x 13 columns]

# %%
outperf = df['creturns'].iloc[-1] - df['cstrategy'].iloc[-1]

# %%
# Buy and hold returns $29.8 on a dollar invested than SMA strategy
outperf
# Out:
# 29.813609120532856
